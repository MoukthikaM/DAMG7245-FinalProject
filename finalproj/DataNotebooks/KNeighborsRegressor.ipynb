# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# Snowpark
from snowflake.snowpark.session import Session
from snowflake.snowpark import functions as F
from snowflake.snowpark.types import *
from snowflake.snowpark.version import VERSION
from snowflake.snowpark.functions import pandas_udf

# %%
# Read credentials
with open('creds.json') as f:
    connection_parameters = json.load(f)    
session = Session.builder.configs(connection_parameters).create()

# %%
snowpark_version = VERSION
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Role                        : {}'.format(session.get_current_role()))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Database                    : "HOUSING"
# Schema                      : "PUBLIC"
# Warehouse                   : "XSMALL_WH"
# Role                        : "ACCOUNTADMIN"
# Snowpark for Python version : 1.0.0

# %%
session.sql("SELECT count(*) FROM HOUSING.PUBLIC.HOUSINGPRICE").collect()
# Out:
# [Row(COUNT(*)=34857)]

# %%
housepricingdf = session.table("HOUSING.PUBLIC.HOUSINGPRICE")

# %%
housepricingdf=housepricingdf.to_pandas()
type(housepricingdf)
# Out:
# pandas.core.frame.DataFrame

# %%
housepricingdf.columns = map(lambda x: str(x).upper(), housepricingdf.columns)

# %%
housepricingdf.head()
# Out:
#          DATE        SUBURB             ADDRESS  ROOMS TYPE      PRICE METHOD  \
# 0  2016-01-28  Surrey Hills  999A Riversdale Rd      3    h  1205000.0      S
# 1  2016-01-28  Surrey Hills    1/10 Florence Rd      2    u   813000.0      S
# 2  2016-01-28    Canterbury   140 Canterbury Rd      4    h        NaN     SP
# 3  2016-03-09  Williamstown       54 Twyford St      3    h  1535000.0      S
# 4  2016-03-09       Newport      1/26 Thorpe St      3    h   826000.0      S
#
#      SELLERG      DATE.1  DISTANCE  ...  BATHROOM  CAR  LANDSIZE  \
# 0  Fletchers  2016-01-28      11.2  ...       1.0  2.0     490.0
# 1  Fletchers  2016-01-28      11.2  ...       1.0  2.0     108.0
# 2  Fletchers  2016-01-28       9.0  ...       2.0  0.0     808.0
# 3       Greg  2016-03-09       8.0  ...       1.0  1.0     507.0
# 4    Village  2016-03-09       8.4  ...       1.0  2.0     281.0
#
#    BUILDINGAREA  YEARBUILT               COUNCILAREA  LATTITUDE LONGTITUDE  \
# 0           NaN        NaN   Boroondara City Council   -37.8361   145.1006
# 1           NaN        NaN   Boroondara City Council   -37.8276   145.1023
# 2         198.0     1910.0   Boroondara City Council   -37.8235   145.0751
# 3         186.0     1910.0  Hobsons Bay City Council   -37.8681   144.8994
# 4         100.0     1957.0  Hobsons Bay City Council   -37.8457   144.8651
#
#               REGIONNAME  PROPERTYCOUNT
# 0  Southern Metropolitan         5457.0
# 1  Southern Metropolitan         5457.0
# 2  Southern Metropolitan         3265.0
# 3   Western Metropolitan         6380.0
# 4   Western Metropolitan         5498.0
#
# [5 rows x 22 columns]

# %%
housepricingdf.isnull().sum()
# Out:
# DATE                 0
# SUBURB               0
# ADDRESS              0
# ROOMS                0
# TYPE                 0
# PRICE             7610
# METHOD               0
# SELLERG              0
# DATE.1               0
# DISTANCE             1
# POSTCODE             1
# BEDROOM2          8217
# BATHROOM          8226
# CAR               8728
# LANDSIZE         11810
# BUILDINGAREA     21115
# YEARBUILT        19306
# COUNCILAREA          3
# LATTITUDE         7976
# LONGTITUDE        7976
# REGIONNAME           3
# PROPERTYCOUNT        3
# dtype: int64

# %%
housepricingdf.nunique()
# Out:
# DATE                78
# SUBURB             351
# ADDRESS          34009
# ROOMS               12
# TYPE                 3
# PRICE             2871
# METHOD               9
# SELLERG            388
# DATE.1              78
# DISTANCE           215
# POSTCODE           211
# BEDROOM2            15
# BATHROOM            11
# CAR                 15
# LANDSIZE          1684
# BUILDINGAREA       740
# YEARBUILT          160
# COUNCILAREA         33
# LATTITUDE        13402
# LONGTITUDE       14524
# REGIONNAME           8
# PROPERTYCOUNT      342
# dtype: int64

# %%
cols=['SUBURB','ROOMS','TYPE','METHOD','SELLERG','REGIONNAME','PROPERTYCOUNT','DISTANCE','COUNCILAREA','BEDROOM2','BATHROOM'
           ,'CAR','LANDSIZE','BUILDINGAREA','PRICE']
housepricingdf=housepricingdf[cols]
housepricingdf
# Out:
#                  SUBURB  ROOMS TYPE METHOD    SELLERG             REGIONNAME  \
# 0          Surrey Hills      3    h      S  Fletchers  Southern Metropolitan
# 1          Surrey Hills      2    u      S  Fletchers  Southern Metropolitan
# 2            Canterbury      4    h     SP  Fletchers  Southern Metropolitan
# 3          Williamstown      3    h      S       Greg   Western Metropolitan
# 4               Newport      3    h      S    Village   Western Metropolitan
# ...                 ...    ...  ...    ...        ...                    ...
# 34852   South Melbourne      2    u     SP     Dingle  Southern Metropolitan
# 34853  South Kingsville      2    t      S    Village   Western Metropolitan
# 34854     Roxburgh Park      4    h      S      Raine  Northern Metropolitan
# 34855      Balwyn North      3    h      S     Jellis  Southern Metropolitan
# 34856      Burwood East      3    h     VB     Rounds   Eastern Metropolitan
#
#        PROPERTYCOUNT  DISTANCE                COUNCILAREA  BEDROOM2  BATHROOM  \
# 0             5457.0      11.2    Boroondara City Council       3.0       1.0
# 1             5457.0      11.2    Boroondara City Council       2.0       1.0
# 2             3265.0       9.0    Boroondara City Council       4.0       2.0
# 3             6380.0       8.0   Hobsons Bay City Council       3.0       1.0
# 4             5498.0       8.4   Hobsons Bay City Council       2.0       1.0
# ...              ...       ...                        ...       ...       ...
# 34852         5943.0       1.9  Port Phillip City Council       NaN       NaN
# 34853          984.0       6.2   Hobsons Bay City Council       2.0       1.0
# 34854         5833.0      20.6          Hume City Council       4.0       2.0
# 34855         7809.0       9.7    Boroondara City Council       3.0       2.0
# 34856         4048.0      14.7    Whitehorse City Council       3.0       2.0
#
#        CAR  LANDSIZE  BUILDINGAREA      PRICE
# 0      2.0     490.0           NaN  1205000.0
# 1      2.0     108.0           NaN   813000.0
# 2      0.0     808.0         198.0        NaN
# 3      1.0     507.0         186.0  1535000.0
# 4      2.0     281.0         100.0   826000.0
# ...    ...       ...           ...        ...
# 34852  NaN       NaN           NaN        NaN
# 34853  1.0     215.0           NaN   730000.0
# 34854  1.0     530.0           0.0   622000.0
# 34855  2.0     863.0           NaN  2315000.0
# 34856  2.0     680.0           NaN  1250000.0
#
# [34857 rows x 15 columns]

# %%
housepricingdf.isnull().sum()
# Out:
# SUBURB               0
# ROOMS                0
# TYPE                 0
# METHOD               0
# SELLERG              0
# REGIONNAME           3
# PROPERTYCOUNT        3
# DISTANCE             1
# COUNCILAREA          3
# BEDROOM2          8217
# BATHROOM          8226
# CAR               8728
# LANDSIZE         11810
# BUILDINGAREA     21115
# PRICE             7610
# dtype: int64

# %%
cols_zero = ['PROPERTYCOUNT','DISTANCE','BEDROOM2','BATHROOM','CAR']
housepricingdf[cols_zero]=housepricingdf[cols_zero].fillna(0)

# %%
housepricingdf.LANDSIZE=housepricingdf.LANDSIZE.fillna(housepricingdf.LANDSIZE.mean())
housepricingdf.BUILDINGAREA=housepricingdf.BUILDINGAREA.fillna(housepricingdf.BUILDINGAREA.mean())

# %%
housepricingdf.dropna(inplace=True)
housepricingdf.isnull().sum()
# Out:
# SUBURB           0
# ROOMS            0
# TYPE             0
# METHOD           0
# SELLERG          0
# REGIONNAME       0
# PROPERTYCOUNT    0
# DISTANCE         0
# COUNCILAREA      0
# BEDROOM2         0
# BATHROOM         0
# CAR              0
# LANDSIZE         0
# BUILDINGAREA     0
# PRICE            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# le.fit(housepricingdf) 
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()
le4=LabelEncoder()
le5=LabelEncoder()
le6=LabelEncoder()
housepricingdf.SUBURB=le1.fit_transform(housepricingdf.SUBURB)
housepricingdf.TYPE = le2.fit_transform(housepricingdf.TYPE)
housepricingdf.METHOD = le3.fit_transform(housepricingdf.METHOD)
housepricingdf.SELLERG=le4.fit_transform(housepricingdf.SELLERG)
housepricingdf.REGIONNAME=le5.fit_transform(housepricingdf.REGIONNAME)
housepricingdf.COUNCILAREA = le6.fit_transform(housepricingdf.COUNCILAREA)
housepricingdf
# Out:
#        SUBURB  ROOMS  TYPE  METHOD  SELLERG  REGIONNAME  PROPERTYCOUNT  \
# 0         295      3     0       1       99           5         5457.0
# 1         295      2     2       1       99           5         5457.0
# 3         333      3     0       1      115           6         6380.0
# 4         231      3     0       1      312           6         5498.0
# 5         231      3     0       3      290           6         5498.0
# ...       ...    ...   ...     ...      ...         ...            ...
# 34850     280      4     0       1      118           2         7969.0
# 34853     278      2     1       1      312           6          984.0
# 34854     268      4     0       1      253           2         5833.0
# 34855      22      3     0       1      142           5         7809.0
# 34856      58      3     0       4      271           0         4048.0
#
#        DISTANCE  COUNCILAREA  BEDROOM2  BATHROOM  CAR  LANDSIZE  BUILDINGAREA  \
# 0          11.2            2       3.0       1.0  2.0     490.0      160.2564
# 1          11.2            2       2.0       1.0  2.0     108.0      160.2564
# 3           8.0           10       3.0       1.0  1.0     507.0      186.0000
# 4           8.4           10       2.0       1.0  2.0     281.0      100.0000
# 5           8.4           10       3.0       2.0  2.0     301.0      195.0000
# ...         ...          ...       ...       ...  ...       ...           ...
# 34850      20.5           29       4.0       2.0  2.0     517.0      160.2564
# 34853       6.2           10       2.0       1.0  1.0     215.0      160.2564
# 34854      20.6           11       4.0       2.0  1.0     530.0        0.0000
# 34855       9.7            2       3.0       2.0  2.0     863.0      160.2564
# 34856      14.7           28       3.0       2.0  2.0     680.0      160.2564
#
#            PRICE
# 0      1205000.0
# 1       813000.0
# 3      1535000.0
# 4       826000.0
# 5      1025000.0
# ...          ...
# 34850   774000.0
# 34853   730000.0
# 34854   622000.0
# 34855  2315000.0
# 34856  1250000.0
#
# [27244 rows x 15 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
X3 = housepricingdf.drop(['PRICE'],axis=1)
y3=housepricingdf.PRICE

# %%
from sklearn.model_selection import train_test_split
X3_train, X3_test, y3_train, y3_test = train_test_split(X3,y3, test_size = .20, random_state= 0)

# %%
knn.fit(X3_train, y3_train)
pred_y=knn.predict(X3_test)

# %%
from sklearn import metrics
# Calculated R Squared
print('R^2 =',metrics.explained_variance_score(y3_test,pred_y))
# Out:
# R^2 = 0.49166603897571604

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y3_test, pred_y))
print('Mean Squared Error:', metrics.mean_squared_error(y3_test, pred_y))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y3_test, pred_y)))
# Out:
# Mean Absolute Error: 280014.4713892457
# Mean Squared Error: 219356251086.71106
# Root Mean Squared Error: 468354.8345930797

# %%
errors = abs(pred_y - y3_test)
MSE=round(np.mean(errors),2)
MAPE=100*(errors/y3_test)
accuracy=round (100 - np.mean(MAPE),2)
print(accuracy)
# Out:
# 70.41

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors' : [3,4,5,6,7,10,15] ,    
              'weights' : ['uniform','distance'] ,
              'algorithm' : ['ball_tree', 'kd_tree', 'brute']}


grid_knn = GridSearchCV(KNeighborsRegressor(), param_grid, cv=5, refit=True, verbose=2, scoring = 'neg_mean_squared_error')

grid_knn.fit(X3_train, y3_train)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END algorithm=ball_tree, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END ..algorithm=kd_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=3, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=3, weights=distance; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=4, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=4, weights=distance; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=5, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=5, weights=distance; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=6, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=6, weights=distance; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END ..algorithm=kd_tree, n_neighbors=7, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=7, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=10, weights=uniform; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=10, weights=distance; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END .algorithm=kd_tree, n_neighbors=15, weights=uniform; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END algorithm=kd_tree, n_neighbors=15, weights=distance; total time=   0.1s
# [CV] END ....algorithm=brute, n_neighbors=3, weights=uniform; total time=   0.3s
# [CV] END ....algorithm=brute, n_neighbors=3, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=3, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=3, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=3, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=3, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=3, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=3, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=3, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=3, weights=distance; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=4, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=4, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=4, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=4, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=4, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=4, weights=distance; total time=   0.3s
# [CV] END ...algorithm=brute, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=4, weights=distance; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=5, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=5, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=5, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=5, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=5, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=5, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=5, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=5, weights=distance; total time=   0.3s
# [CV] END ...algorithm=brute, n_neighbors=5, weights=distance; total time=   0.5s
# [CV] END ...algorithm=brute, n_neighbors=5, weights=distance; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=6, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=6, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=6, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=6, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=6, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=6, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=6, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=6, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=6, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=6, weights=distance; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=7, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=7, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=7, weights=uniform; total time=   0.2s
# [CV] END ....algorithm=brute, n_neighbors=7, weights=uniform; total time=   0.3s
# [CV] END ....algorithm=brute, n_neighbors=7, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=7, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=7, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=7, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=7, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=7, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=10, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=10, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=10, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=10, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=10, weights=uniform; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=10, weights=distance; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=15, weights=uniform; total time=   0.3s
# [CV] END ...algorithm=brute, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END ...algorithm=brute, n_neighbors=15, weights=uniform; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=15, weights=distance; total time=   0.2s
# [CV] END ..algorithm=brute, n_neighbors=15, weights=distance; total time=   0.2s
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 4, 5, 6, 7, 10, 15],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
best_score = np.sqrt(-grid_knn.best_score_)
print(best_score)    
print(grid_knn.best_params_)
print(grid_knn.best_estimator_)
# Out:
# 455895.3680106101
# {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'distance'}
# KNeighborsRegressor(algorithm='ball_tree', n_neighbors=7, weights='distance')

# %%
pred_knn = grid_knn.predict(X3_test)

# %%
from sklearn import metrics
# Calculated R Squared
print('R^2 =',metrics.explained_variance_score(y3_test,pred_knn))
# Out:
# R^2 = 0.5035310116165561

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y3_test, pred_knn))
print('Mean Squared Error:', metrics.mean_squared_error(y3_test, pred_knn))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y3_test, pred_knn)))
# Out:
# Mean Absolute Error: 272531.53419004736
# Mean Squared Error: 214434999016.0535
# Root Mean Squared Error: 463071.2677504981

# %%
errors = abs(pred_knn - y3_test)
MSE=round(np.mean(errors),2)
MAPE=100*(errors/y3_test)
accuracy=round (100 - np.mean(MAPE),2)
print(accuracy)
# Out:
# 71.62

# %%
df3= pd.DataFrame({'Actual_Price': np.round(y3_test), 
                   'Predicted_Price': np.round(pred_knn),
                 })
df3['difference']=df3.apply(lambda x: x.Predicted_Price-x.Actual_Price,axis=1)
df3.head(10)
# Out:
#        Actual_Price  Predicted_Price  difference
# 12062      730000.0         853665.0    123665.0
# 26643      700000.0         771145.0     71145.0
# 30082     1007000.0         637414.0   -369586.0
# 18964     1060000.0        1043835.0    -16165.0
# 4295      1550000.0        1783829.0    233829.0
# 6267       241000.0         478170.0    237170.0
# 9875       780000.0         748445.0    -31555.0
# 7746      2857000.0        1245000.0  -1612000.0
# 27110      770000.0         689870.0    -80130.0
# 20645      500000.0         627558.0    127558.0

# %%
# Creating a User Defined Function within Snowflake to do the scoring there
def predict_pandas_udf_KNR(df3: pd.DataFrame) -> pd.Series:
    return pd.Series(grid_knn.predict(df3))

# %%
housepricingdf.columns = map(lambda x: str(x).upper(), housepricingdf.columns)
snowdf_details = session.createDataFrame(housepricingdf)
snowdf_details.show()
snowdf_details.write.mode("overwrite").saveAsTable("HOUSING.PUBLIC.FULL_HOUSINGPRICE_encoded_KNR") 

session.table("HOUSING.PUBLIC.FULL_HOUSINGPRICE_encoded_KNR").show(5)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"SUBURB"  |"ROOMS"  |"TYPE"  |"METHOD"  |"SELLERG"  |"REGIONNAME"  |"PROPERTYCOUNT"  |"DISTANCE"  |"COUNCILAREA"  |"BEDROOM2"  |"BATHROOM"  |"CAR"  |"LANDSIZE"  |"BUILDINGAREA"     |"PRICE"    |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |295       |3        |0       |1         |99         |5             |5457.0           |11.2        |2              |3.0         |1.0         |2.0    |490.0       |160.2564003565711  |1205000.0  |
# |295       |2        |2       |1         |99         |5             |5457.0           |11.2        |2              |2.0         |1.0         |2.0    |108.0       |160.2564003565711  |813000.0   |
# |333       |3        |0       |1         |115        |6             |6380.0           |8.0         |10             |3.0         |1.0         |1.0    |507.0       |186.0              |1535000.0  |
# |231       |3        |0       |1         |312        |6             |5498.0           |8.4         |10             |2.0         |1.0         |2.0    |281.0       |100.0              |826000.0   |
# |231       |3        |0       |3         |290        |6             |5498.0           |8.4         |10             |3.0         |2.0         |2.0    |301.0       |195.0              |1025000.0  |
# |222       |1        |2       |1         |255        |5             |2555.0           |14.6        |12             |1.0         |1.0         |1.0    |106.0       |51.0               |380500.0   |
# |222       |3        |0       |1         |215        |5             |2555.0           |14.6        |12             |3.0         |2.0         |2.0    |573.0       |150.0              |1000000.0  |
# |222       |3        |0       |1         |48         |5             |2555.0           |14.6        |12             |3.0         |1.0         |3.0    |771.0       |160.2564003565711  |1020000.0  |
# |222       |3        |0       |1         |48         |5             |2555.0           |14.6        |12             |3.0         |1.0         |3.0    |834.0       |143.0              |1224000.0  |
# |221       |3        |2       |1         |206        |6             |6232.0           |6.9         |22             |3.0         |2.0         |2.0    |0.0         |120.0              |670000.0   |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"SUBURB"  |"ROOMS"  |"TYPE"  |"METHOD"  |"SELLERG"  |"REGIONNAME"  |"PROPERTYCOUNT"  |"DISTANCE"  |"COUNCILAREA"  |"BEDROOM2"  |"BATHROOM"  |"CAR"  |"LANDSIZE"  |"BUILDINGAREA"     |"PRICE"    |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |295       |3        |0       |1         |99         |5             |5457.0           |11.2        |2              |3.0         |1.0         |2.0    |490.0       |160.2564003565711  |1205000.0  |
# |295       |2        |2       |1         |99         |5             |5457.0           |11.2        |2              |2.0         |1.0         |2.0    |108.0       |160.2564003565711  |813000.0   |
# |333       |3        |0       |1         |115        |6             |6380.0           |8.0         |10             |3.0         |1.0         |1.0    |507.0       |186.0              |1535000.0  |
# |231       |3        |0       |1         |312        |6             |5498.0           |8.4         |10             |2.0         |1.0         |2.0    |281.0       |100.0              |826000.0   |
# |231       |3        |0       |3         |290        |6             |5498.0           |8.4         |10             |3.0         |2.0         |2.0    |301.0       |195.0              |1025000.0  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
KNR_model_vec = pandas_udf(func=predict_pandas_udf_KNR,
                                return_type=FloatType(),
                                input_types=[IntegerType(),IntegerType(),IntegerType(),IntegerType(),IntegerType(),IntegerType(),FloatType(),FloatType(),FloatType(),IntegerType(),FloatType(),FloatType(),FloatType(),FloatType()],
                                session=session,
                                packages = ("pandas","scikit-learn"), max_batch_size=200)

# %%
# Calling the UDF to do the scoring (pushing down to Snowflake)
output_KNR = session.table('HOUSING.PUBLIC.FULL_HOUSINGPRICE_encoded_KNR').select(*list(X3.columns),
                    KNR_model_vec(list(X3.columns)).alias('PREDICTED_PRICE'),
                    (F.col('Price')).alias('ACTUAL_PRICE')                                              
                    )

output_KNR.show(5)
# Out:
# ---------------------------------------------------------------------------
# SnowparkSessionException                  Traceback (most recent call last)
# Cell In [46], line 3
#       1 # Calling the UDF to do the scoring (pushing down to Snowflake)
#       2 output_KNR = session.table('HOUSING.PUBLIC.FULL_HOUSINGPRICE_encoded_KNR').select(*list(X3.columns),
# ----> 3                     KNR_model_vec(list(X3.columns)).alias('PREDICTED_PRICE'),
#       4                     (F.col('Price')).alias('ACTUAL_PRICE')
#       5                     )
#       7 output_KNR.show(5)
#
# File ~/Downloads/conda/envs/snowpark/lib/python3.8/site-packages/snowflake/snowpark/udf.py:89, in UserDefinedFunction.__call__(self, *cols)
#      84     else:
#      85         raise TypeError(
#      86             f"The input of UDF {self.name} must be Column, column name, or a list of them"
#      87         )
# ---> 89 session = snowflake.snowpark.context.get_active_session()
#      90 session._conn._telemetry_client.send_function_usage_telemetry(
#      91     "UserDefinedFunction.__call__", TelemetryField.FUNC_CAT_USAGE.value
#      92 )
#      93 return Column(self._create_udf_expression(exprs))
#
# File ~/Downloads/conda/envs/snowpark/lib/python3.8/site-packages/snowflake/snowpark/context.py:19, in get_active_session()
#      11 def get_active_session() -> "snowflake.snowpark.Session":
#      12     """Returns the current active Snowpark session.
#      13
#      14     Raises: SnowparkSessionException: If there is more than one active session or no active sessions.
#    (...)
#      17         A :class:`Session` object for the current session.
#      18     """
# ---> 19     return snowflake.snowpark.session._get_active_session()
#
# File ~/Downloads/conda/envs/snowpark/lib/python3.8/site-packages/snowflake/snowpark/session.py:140, in _get_active_session()
#     138     return next(iter(_active_sessions))
#     139 elif len(_active_sessions) > 1:
# --> 140     raise SnowparkClientExceptionMessages.MORE_THAN_ONE_ACTIVE_SESSIONS()
#     141 else:
#     142     raise SnowparkClientExceptionMessages.SERVER_NO_DEFAULT_SESSION()
#
# SnowparkSessionException: (1409): More than one active session is detected. When you call function 'udf' or use decorator '@udf', you must specify the 'session' parameter if you created multiple sessions.Alternatively, you can use 'session.udf.register' to register UDFs

# %%
output_KNR=output_KNR.to_pandas()
output_KNR.head()

# %%
output_KNR.SUBURB=le1.inverse_transform(output_KNR.SUBURB)
output_KNR.TYPE = le2.inverse_transform(output_KNR.TYPE)
output_KNR.METHOD = le3.inverse_transform(output_KNR.METHOD)
output_KNR.SELLERG=le4.inverse_transform(output_KNR.SELLERG)
output_KNR.REGIONNAME=le5.inverse_transform(output_KNR.REGIONNAME)
output_KNR.COUNCILAREA = le6.inverse_transform(output_KNR.COUNCILAREA)

# %%
output_KNR.head()

# %%
snowdf_details_KNR = session.createDataFrame(output_KNR)
snowdf_details_KNR.show()
snowdf_details_KNR.write.mode("overwrite").saveAsTable("HOUSING.PUBLIC.FULL_HOUSINGPRICE_PREDICTED_KNR")

# %%
# Also get a local dataframe to review the results
snowdf_details_KNR=snowdf_details_KNR.toPandas()
snowdf_details_KNR
